# %%
import pandas as pd
import openpyxl
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
plt.rcParams["axes.unicode_minus"] = False 
rc("font", family="Arial Unicode MS") # Windows: Malgun Gothic 
# %matplotlib inline 
get_ipython().run_line_magic("matplotlib", "inline")

# %%
df = pd.read_csv("버스_출근퇴근_총_인원정보(최종).csv", index_col=0)
df
# Out:
# /var/folders/hr/y8znbyhd4058w4d5l14qqsv80000gn/T/ipykernel_34144/2041198187.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("버스_출근퇴근_총_인원정보(최종).csv", index_col=0)
#            사용년월  노선번호                노선명  표준버스정류장ID            역명          경도  \
# 0        201801   100     100번(하계동~용산구청)  100000002   창경궁.서울대학교병원  126.996566
# 1        201801   100     100번(하계동~용산구청)  100000003     명륜3가.성대입구  126.998340
# 2        201801   100     100번(하계동~용산구청)  100000005        혜화동로터리  127.001744
# 3        201801   100     100번(하계동~용산구청)  100000102           원남동  126.997338
# 4        201801   100     100번(하계동~용산구청)  100000108      종로5가.효제동  127.002230
# ...         ...   ...                ...        ...           ...         ...
# 1834733  202112  중랑02  중랑02(진로아파트~한신아파트)  106900025         새마을금고  127.097322
# 1834734  202112  중랑02  중랑02(진로아파트~한신아파트)  106900026     진주빌라.바다약국  127.100663
# ...

# %%
df_sum = df.pivot_table(index='사용년월',aggfunc='sum')
df_mean = df.pivot_table(index='사용년월',aggfunc='mean')
df_count = df.pivot_table(index='사용년월',aggfunc='count')

# %%
df_sum
# Out:
#                   경도            위도      총 이동량        출근        퇴근
# 사용년월
# 201801  4.769998e+06  1.410532e+06   77784911  36601611  41183300
# 201802  4.764919e+06  1.409030e+06   66828175  31430587  35397588
# 201803  4.799339e+06  1.419196e+06   84553932  40628863  43925069
# 201804  4.775329e+06  1.412110e+06   81517023  39641589  41875434
# 201805  4.772545e+06  1.411266e+06   82441577  39501121  42940456
# 201806  4.774448e+06  1.411830e+06   78194021  37323880  40870141
# 201807  4.776861e+06  1.412545e+06   83285292  39922944  43362348
# 201808  4.795410e+06  1.418030e+06   81515625  38628250  42887375
# 201809  4.779655e+06  1.413371e+06   75031366  35468446  39562920
# 201810  4.801872e+06  1.419957e+06   83872749  40573131  43299618
# 201811  4.819644e+06  1.425208e+06   83126226  40522498  42603728
# 201812  4.830938e+06  1.428544e+06   77733932  36983070  40750862
# 201901  4.789678e+06  1.416351e+06   77053288  36230934  40822354
# ...

# %%
fig, ax = plt.subplots()

ax.plot(df_mean[])
# Out:
#   Input In [13]
#     ax.plot(df_mean[])
#                     ^
# SyntaxError: invalid syntax

# %%
df_202101 = pd.read_csv("2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(01월).csv", encoding='cp949')
df_202101
# Out:
#          사용년월  노선번호              노선명  표준버스정류장ID 버스정류장ARS번호               역명  \
# 0      202101   100   100번(하계동~용산구청)  100000002      01002      창경궁.서울대학교병원
# 1      202101   100   100번(하계동~용산구청)  100000003      01003        명륜3가.성대입구
# 2      202101   100   100번(하계동~용산구청)  100000005      01005    혜화동로터리.여운형활동터
# 3      202101   100   100번(하계동~용산구청)  100000102      01198              원남동
# 4      202101   100   100번(하계동~용산구청)  100000108      01204  종로5가.효제동.김상옥의거터
# ...       ...   ...              ...        ...        ...              ...
# 39091  202101  9714  9714번(교하운정~서울역)  229000856      63658            우리은행앞
# 39092  202101  9714  9714번(교하운정~서울역)  229000857      63660             중앙공원
# 39093  202101  9714  9714번(교하운정~서울역)  229000858      63675            책향기마을
# 39094  202101  9714  9714번(교하운정~서울역)  229001662      63736            교하차고지
# 39095  202101  9714  9714번(교하운정~서울역)  229001663      63737            교하차고지
#
# ...

# %%
df_202101.keys()
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
#        '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '등록일자'],
#       dtype='object')

# %%
df_202101.drop(columns=['00시승차총승객수',
       '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
       '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
       '6시하차총승객수', '7시승차총승객수',],inplace=True)
df_202101.keys()
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '7시하차총승객수',
#        '8시승차총승객수', '8시하차총승객수', '9시승차총승객수', '9시하차총승객수', '10시승차총승객수',
#        '10시하차총승객수', '11시승차총승객수', '11시하차총승객수', '12시승차총승객수', '12시하차총승객수',
#        '13시승차총승객수', '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', '15시승차총승객수',
#        '15시하차총승객수', '16시승차총승객수', '16시하차총승객수', '17시승차총승객수', '17시하차총승객수',
#        '18시승차총승객수', '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수',
#        '20시하차총승객수', '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수',
#        '23시승차총승객수', '23시하차총승객수', '등록일자'],
#       dtype='object')

# %%
df_202101.drop(columns=['8시승차총승객수','9시승차총승객수','10시승차총승객수','11시승차총승객수', '11시하차총승객수', '12시승차총승객수', '12시하차총승객수',
       '13시승차총승객수', '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', '15시승차총승객수',
       '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',],inplace=True)
df_202101.keys()
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '7시하차총승객수',
#        '8시하차총승객수', '9시하차총승객수', '10시하차총승객수', '17시승차총승객수', '17시하차총승객수',
#        '18시승차총승객수', '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수',
#        '20시하차총승객수', '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수',
#        '23시승차총승객수', '23시하차총승객수', '등록일자'],
#       dtype='object')

# %%
df_202101.drop(columns=['17시하차총승객수','18시하차총승객수','19시하차총승객수','20시하차총승객수','21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수',
       '23시승차총승객수', '23시하차총승객수', '등록일자'],inplace=True)
df_202101.keys()
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '7시하차총승객수',
#        '8시하차총승객수', '9시하차총승객수', '10시하차총승객수', '17시승차총승객수', '18시승차총승객수',
#        '19시승차총승객수', '20시승차총승객수'],
#       dtype='object')

# %%
df_202101.sum()
# Out:
# 사용년월                                                 7901340696
# 노선번호          1001001001001001001001001001001001001001001001...
# 노선명           100번(하계동~용산구청)100번(하계동~용산구청)100번(하계동~용산구청)100번...
# 표준버스정류장ID                                         5000425488527
# 버스정류장ARS번호    0100201003010050119801204012050121201219012200...
# 역명            창경궁.서울대학교병원명륜3가.성대입구혜화동로터리.여운형활동터원남동종로5가.효제동.김...
# 7시하차총승객수                                                5381442
# 8시하차총승객수                                                9106267
# 9시하차총승객수                                                6230333
# 10시하차총승객수                                               4512159
# 17시승차총승객수                                               7408046
# 18시승차총승객수                                               8819085
# 19시승차총승객수                                               6341229
# 20시승차총승객수                                               5019339
# dtype: object

# %%
df_202101.sum().iloc[6:].sum()
# 202101	4.828190e+06	1.427709e+06	105635800	50460402	55175398
# Out:
# 52817900

# %%
52817900*2
# Out:
# 105635800
