# %%
import pandas as pd

# %%
df = pd.read_csv("2018_2021년 버스(지하철정보+출퇴근).csv", index_col=0)
df.head()
# Out:
#       정류장_ID     정류장_명칭 정류장_유형   정류장_번호          위도         경도  \
# 0  717104358  계수사거리(경유)  가상정류장      0.0  126.817473  37.452473
# 1  500000288      행사장입구   마을버스  25965.0  126.691556  37.321742
# 2  500000287      행사장입구   마을버스  25095.0  126.691728  37.321942
# 3  500000286      아남중전기   일반차로  25963.0  126.710485  37.319934
# 4  500000285         3Z   일반차로  25964.0  126.707130  37.320566
#
#   버스도착정보안내기_설치_여부  line name    code        lat         lng  distance    출근  \
# 0           미설치    01호선   역곡  1803.0  37.485178  126.811502       3.0  2224
# 1           미설치    04호선   정왕  1761.0  37.351735  126.742989       5.0  1893
# 2           미설치    04호선   정왕  1761.0  37.351735  126.742989       5.0  1491
# 3           미설치    04호선   정왕  1761.0  37.351735  126.742989       4.0  2400
# 4           미설치    04호선   정왕  1761.0  37.351735  126.742989       4.0   173
#
#      퇴근  총이동량
# 0   384  2608
# 1   770  2663
# 2   281  1772
# 3  1424  3824
# 4   466   639

# %%
df['distance'].describe()
# Out:
# count    69939.000000
# mean         6.737876
# std         72.827084
# min          0.000000
# 25%          0.415973
# 50%          1.595443
# 75%          5.621082
# max      13138.413037
# Name: distance, dtype: float64

# %%
df_mask = (df['distance']<df['distance'].describe()['25%'])
filtered_df = df[df_mask]
filtered_df
# Out:
#           정류장_ID         정류장_명칭 정류장_유형   정류장_번호          위도         경도  \
# 96     500000167          성환터미널   일반차로      0.0  127.132673  36.916849
# 201    277101873      뱅뱅사거리(경유)   일반차로  78037.0  127.031746  37.489806
# 207    277101867  역삼동.우성아파트(경유)   일반차로  78036.0  127.030457  37.491367
# 214    277101860   도곡1동주민센터(경유)   일반차로  78035.0  127.040832  37.492126
# 221    277101853     강남역사거리(경유)   일반차로      0.0  127.028273  37.498512
# ...          ...            ...    ...      ...         ...        ...
# 69937  100000005  혜화동로터리.여운형활동터   중앙차로   1005.0  127.001744  37.586243
# 69938  100000004       종로2가.삼일교   중앙차로   1004.0  126.987613  37.568579
# 69939  100000003      명륜3가.성대입구   중앙차로   1003.0  126.998340  37.582671
# 69940  100000002    창경궁.서울대학교병원   중앙차로   1002.0  126.996566  37.579183
# 69941  100000001        종로2가사거리   중앙차로   1001.0  126.987750  37.569765
#
#       버스도착정보안내기_설치_여부  line   name    code        lat         lng  distance  \
# ...

# %%
df_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   line    474 non-null    object
#  1   name    474 non-null    object
#  2   출근      474 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 11.2+ KB

# %%
df_sum = pd.pivot_table(data=filtered_df, index=['line', 'name'], values='출근', aggfunc='sum').reset_index()
df_sum.sort_values('출근', ascending=False)[0:20]
# Out:
#      line     name      출근
# 35   01호선       백운  198067
# 55   01호선       수원  177789
# 64   01호선       역곡  176901
# 79   01호선     종로3가  145708
# 3    01호선       개봉  133306
# 1    01호선  가산디지털단지  126601
# 41   01호선       부평  122020
# 160  03호선       삼송  119111
# 170  03호선       원당  118375
# 11   01호선     금천구청  116635
# 5    01호선       광명  115082
# 180  03호선       화정  113682
# 2    01호선       간석  113134
# 175  03호선       주엽  110441
# 107  02호선       방배  107982
# 77   01호선      제물포  104866
# 36   01호선       병점  103782
# 171  03호선       원흥  100675
# 40   01호선       부천  100128
# 145  03호선       금호   99742

# %%
df_sum.to_csv('버스_지하철역부근_출근.csv')
