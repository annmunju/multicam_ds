# %% [markdown]
# # 로지스틱 회귀(Logistic Regression)

# %% [markdown]
# - 선형회귀방식을 분류에 적용한 알고리즘

# %% [markdown]
# ### 사이킷런의 로지스틱 회귀 클래스 LogistricRegression

# %% [raw]
# LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)

# %% [markdown]
# https://sci2lab.github.io/ml_tutorial/logistic_regression/

# %% [markdown]
# **주요 매개변수**
# - penalty : 규제 유형, 'l1', 'l2'
# - C : 규제 강도 조절 alpha의 역수, C값이 클수록 규제강도가 큼

# %% [markdown]
# ### 유방암 분류 문제

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression

cancer = load_breast_cancer()

# %%
cancerDF = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancerDF.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# 각 피처에 대한 분포도 확인
import seaborn as sns

fig, axs = plt.subplots(figsize=(22, 22), nrows=6, ncols=5)

for i, feature in enumerate(cancer.feature_names):
    row = i // 5
    col = i % 5
    sns.histplot(cancerDF[feature], ax = axs[row][col])

# %% [markdown]
# **피처변수들의 Z-스케일링**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# StandardScaler( )로 평균이 0, 분산 1로 데이터 분포도 변환
scaler = StandardScaler()
scaled_data = scaler.fit_transform(cancer.data)

# %%
# 각 피처에 대한 분포도 확인
import seaborn as sns

scaled_data_df = pd.DataFrame(data=scaled_data, columns=cancer.feature_names)
fig, axs = plt.subplots(figsize=(22, 22), nrows=6, ncols=5)

for i, feature in enumerate(cancer.feature_names):
    row = i // 5
    col = i % 5
    sns.histplot(scaled_data_df[feature], ax = axs[row][col])

# %% [markdown]
# **로지스틱 회귀를 이용하여 학습 및 예측 수행**

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

X_train, X_test, y_train, y_test = train_test_split(scaled_data, cancer.target, random_state=0, test_size=0.3)

# 로지스틱 회귀를 이용하여 학습 및 예측 수행. 

lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)

# accuracy와 roc_auc 측정
print('Accuracy : {:.3f}'.format(accuracy_score(y_test, pred)))
print('roc_auc : {:.3f}'.format(roc_auc_score(y_test, pred)))
# Out:
# Accuracy : 0.977
# roc_auc : 0.972

# %% [markdown]
# **로지스틱회귀에서 규제를 적용한 최적의 모델 검증**

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

params = {'C':[0.01, 0.1, 1, 1.5, 10], 'penalty':['l1', 'l2']}

lr_clf = LogisticRegression()
grid_clf = GridSearchCV(lr_clf, params, scoring='accuracy', cv=3)

grid_clf.fit(scaled_data, cancer.target)
print('최적의 파라미터 :',grid_clf.best_params_)
print('최적의 평균 정확도 : {:.3f}'.format(grid_clf.best_score_))
# Out:
# 최적의 파라미터 : {'C': 1, 'penalty': 'l2'}
# 최적의 평균 정확도 : 0.975

# %% [markdown]
# # 회귀 트리(Regression Tree)

# %% [markdown]
# - 트리 기반의 회귀 알고리즘
# - 트리 생성 방식은 분류 트리와 같으나, 리프 노드에서 예측 결정 값을 만드는 과정이 다름
#     - 리프 노드에 속하는 데이터 값의 평균값을 구해 회귀 예측값으로 결정

# %% [markdown]
# ### 사이킷런의 회귀를 위한 결정 트리 기반의 클래스들
#
# - 결정트리, 랜덤포레스트, GBM, XGBoost, LightGBM 모두 회귀 분석 가능
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 보스턴 주택 가격 예측 문제

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np

# 데이터 로드 -> target, feature 
boston = load_boston()

X = boston.data
y = boston.target

# 모델 객체 생성 : RandomForestRegressor
rf_reg = RandomForestRegressor(random_state=0, n_estimators=1000)

# cross_val_score 이용해서 교차검증 : cv = 5
neg_mse = cross_val_score(rf_reg, X, y, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
mse = neg_mse * (-1)
rmse = np.sqrt(mse)
rmse_avg = np.mean(rmse)

print('5 교차 검증의 개별 Negative MSE scores:', np.round(neg_mse, 2))
print('5 교차 검증의 개별 RMSE scores:', np.round(rmse,2))
print('5 교차 검증의 평균 RMSE scores:', np.round(rmse_avg,3))
# Out:
# 5 교차 검증의 개별 Negative MSE scores: [ -7.88 -13.14 -20.57 -46.23 -18.88]
# 5 교차 검증의 개별 RMSE scores: [2.81 3.63 4.54 6.8  4.34]
# 5 교차 검증의 평균 RMSE scores: 4.423

# %%
def get_model_cv_prediction(model, X_data, y_target, scoring='neg_mean_squared_error'):

    # cross_val_score 이용해서 교차검증 : cv = 5
    neg_mse = cross_val_score(model, X_data, y_target, scoring=scoring, cv=5, n_jobs=-1)

    mse = neg_mse * (-1)
    rmse = np.sqrt(mse)
    rmse_avg = np.mean(rmse)

    print('####', model.__class__.__name__, '####')
    print('5 교차 검증의 개별 Negative MSE scores:', np.round(neg_mse, 2))
    print('5 교차 검증의 개별 RMSE scores:', np.round(rmse,2))
    print('5 교차 검증의 평균 RMSE scores:', np.round(rmse_avg,3))

# %%
# 데이터 로드 -> target, feature 
boston = load_boston()

X = boston.data
y = boston.target

# 모델 객체 생성 : RandomForestRegressor
rf_reg = RandomForestRegressor(random_state=0, n_estimators=1000)

get_model_cv_prediction(rf_reg, X, y)
# Out:
# #### RandomForestRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [ -7.88 -13.14 -20.57 -46.23 -18.88]
# 5 교차 검증의 개별 RMSE scores: [2.81 3.63 4.54 6.8  4.34]
# 5 교차 검증의 평균 RMSE scores: 4.423

# %% [markdown]
# **다양한 유형의 회귀트리를 생성하고 보스턴 주택 가격 예측**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor


# 트리 기반의 회귀 모델을 반복하면서 평가 수행 

dt_reg = DecisionTreeRegressor(random_state=0, max_depth=4)

rf_reg = RandomForestRegressor(random_state=0, n_estimators=1000)

gbm_reg = GradientBoostingRegressor(random_state=0, n_estimators=1000)

xgb_reg = XGBRegressor()

lgbm_reg = LGBMRegressor(random_state=0)

models = [dt_reg, rf_reg, gbm_reg, xgb_reg, lgbm_reg]

for model in models :
    get_model_cv_prediction(model, X, y)
# Out:
# #### DecisionTreeRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [-11.94 -36.25 -29.63 -47.23 -65.56]
# 5 교차 검증의 개별 RMSE scores: [3.46 6.02 5.44 6.87 8.1 ]
# 5 교차 검증의 평균 RMSE scores: 5.978
# #### RandomForestRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [ -7.88 -13.14 -20.57 -46.23 -18.88]
# 5 교차 검증의 개별 RMSE scores: [2.81 3.63 4.54 6.8  4.34]
# 5 교차 검증의 평균 RMSE scores: 4.423
# #### GradientBoostingRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [ -7.52 -14.52 -19.57 -39.45 -16.72]
# 5 교차 검증의 개별 RMSE scores: [2.74 3.81 4.42 6.28 4.09]
# 5 교차 검증의 평균 RMSE scores: 4.269
# /opt/homebrew/Caskroom/miniforge/base/envs/multi_crawling/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/homebrew/Caskroom/miniforge/base/envs/multi_crawling/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# #### XGBRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [ -9.17 -13.74 -13.95 -41.77 -18.68]
# 5 교차 검증의 개별 RMSE scores: [3.03 3.71 3.74 6.46 4.32]
# 5 교차 검증의 평균 RMSE scores: 4.251
# #### LGBMRegressor ####
# 5 교차 검증의 개별 Negative MSE scores: [ -9.   -15.73 -18.18 -43.95 -24.96]
# 5 교차 검증의 개별 RMSE scores: [3.   3.97 4.26 6.63 5.  ]
# 5 교차 검증의 평균 RMSE scores: 4.571

# %% [markdown]
# **회귀트리의 피처변수별 중요도**
# - Regressor 클래스는 회귀계수 제공 속성 coef_ 가 없음
# - 대신 feature_importances_를 이용해 피처별 중요도 제공

# %%
import seaborn as sns
# %matplotlib inline

rf_reg = RandomForestRegressor(n_estimators=1000)

# 앞 예제에서 만들어진 X_data, y_target 데이터 셋을 적용하여 학습합니다.   
rf_reg.fit(X, y)

feature_series = pd.Series(data=rf_reg.feature_importances_, index=boston.feature_names)
feature_series = feature_series.sort_values(ascending=False)
sns.barplot(x= feature_series, y=feature_series.index)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 주택가격 데이터 셋에서  'RM' 변수와 'PRICE' 변수 만 선택하여 단순회귀분석
# - 독립변수 : 'RM' (거주할 수 있는 방의 수)
# - 종속변수 : 'PRICE' (주택 가격)
# - 데이터 개수 : 100

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

bostonDF = pd.DataFrame(data=boston.data, columns=boston.feature_names)
bostonDF['PRICE'] = boston.target

bostonDF_sample = bostonDF[['RM','PRICE']]
bostonDF_sample = bostonDF_sample.sample(n=100,random_state=0)
print(bostonDF_sample.shape)
plt.figure()
plt.scatter(bostonDF_sample.RM , bostonDF_sample.PRICE,c="darkorange")
plt.show()
# Out:
# (100, 2)

# %% [markdown]
# **회귀트리로 주택가격 예측**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# 선형 회귀와 결정 트리 기반의 Regressor 생성. DecisionTreeRegressor의 max_depth는 각각 2, 7
lr_reg = LinearRegression()
rf_reg2 = DecisionTreeRegressor(max_depth=2)
rf_reg7 = DecisionTreeRegressor(max_depth=7)

# 실제 예측을 적용할 테스트용 데이터 셋을 4.5 ~ 8.5 까지 100개 데이터 셋 생성. 
X_test = np.arange(4.5, 8.5, 0.04).reshape(-1, 1)

# 보스턴 주택가격 데이터에서 시각화를 위해 피처는 RM만, 그리고 결정 데이터인 PRICE 추출
X_feature = bostonDF_sample['RM'].values.reshape(-1,1)
y_target = bostonDF_sample['PRICE'].values.reshape(-1,1)

# 학습과 예측 수행. 
lr_reg.fit(X_feature, y_target)
rf_reg2.fit(X_feature, y_target)
rf_reg7.fit(X_feature, y_target)

pred_lr = lr_reg.predict(X_test)
pred_rf2 = rf_reg2.predict(X_test)
pred_rf7 = rf_reg7.predict(X_test)

# %% [markdown]
# **에측한 회귀직선 시각화**

# %%
fig , (ax1, ax2, ax3) = plt.subplots(figsize=(14,4), ncols=3)

# X축값을 4.5 ~ 8.5로 변환하며 입력했을 때, 선형 회귀와 결정 트리 회귀 예측 선 시각화
# 선형 회귀로 학습된 모델 회귀 예측선 
ax1.set_title('Linear Regression')
ax1.scatter(bostonDF_sample.RM, bostonDF_sample.PRICE, c="darkorange")
ax1.plot(X_test, pred_lr,label="linear", linewidth=2 )

# DecisionTreeRegressor의 max_depth를 2로 했을 때 회귀 예측선 
ax2.set_title('Decision Tree Regression: \n max_depth=2')
ax2.scatter(bostonDF_sample.RM, bostonDF_sample.PRICE, c="darkorange")
ax2.plot(X_test, pred_rf2, label="max_depth:3", linewidth=2 )

# DecisionTreeRegressor의 max_depth를 7로 했을 때 회귀 예측선 
ax3.set_title('Decision Tree Regression: \n max_depth=7')
ax3.scatter(bostonDF_sample.RM, bostonDF_sample.PRICE, c="darkorange")
ax3.plot(X_test, pred_rf7, label="max_depth:7", linewidth=2)

plt.show()
